# %%
def d(x):
    return x**2+2*x
print(d(3))

# %% [markdown]
# #Review q 5
# 2x+y=13, 10x-2y=44

# %%
def f(x):
    xx=x
    #if(xx==1):
    #    return 0
    v = xx**2/(xx-1)
    #if v**2 > 100:
    #    return 0
    return v

import numpy as np
import numpy.ma as ma

# %matplotlib inline
from matplotlib import pyplot as plt

xs = np.arange(-10,10,.25)
#xs2 = ma.masked_equal(xs, 1)
#y = (from xx in xs)
#print(xs2)
plt.plot(xs,f(xs))
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/ipykernel/__main__.py:5: RuntimeWarning: divide by zero encountered in true_divide

# %%
def f(x):
    return 4*x**2 - 2*x +1

#for y in x:
#    print (f(y))
import numpy as np`
# %matplotlib inline
from matplotlib import pyplot as plt

x = np.array(range(-100,100))

plt.plot(x,f(x))

# %%
import pandas as pd
import numpy as numpy

df1=pd.DataFrame({'x':numpy.arange(4,6,0.5)})
df1['y']=(13-df1['x']*2)
df2=pd.DataFrame({'y':numpy.arange(2,4,0.5)})
df2['x']=(44+2*df2['y'])/10
#df1
#df2
numpy.arange(0,5,0.5)
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5])

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
plt.plot(df1.x, df1.y,color="blue")
plt.plot(df2.x, df2.y,color="red")
