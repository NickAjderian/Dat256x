# %% [markdown]
# # Nicks Azure Notebooks and DAT256 course cheat sheet
#
# Start your notebooks at https://notebooks.azure.com/
#
# Notebooks cheat sheet at https://notebooks.azure.com/anon-xqazxq/projects/introprog-cheatsheet/html/cheatsheet.ipynb

# %%
print(2==3) #prints the result

def the_answer(lifetheuniverseandeverything):
    return 42

answers = [the_answer(q) for q in range(2,4) ]

print(answers)

'hello: the answer is ...is ...IS...  ' +  str(the_answer('stuff')) # str() converts number to string. this is the last line, gets printed

for
# Out:
# False
# [42, 42]
# 'hello: the answer is ...is ...IS...  42'

# %%
print(17%6) #remainder
1+2*3-4/5**6 ##normal maths ops
# Out:
# 5
# 6.999744

# %%
import pandas as pd #https://pandas.pydata.org/docs/user_guide/index.html
# Create a dataframe with an x column containing values from -10 to 10
df = pd.DataFrame ({'x': range(-5, 6)})

# Add a y column by applying the solved equation to x
df['y'] = (3*pow(df['x'],2) - 4) / 2

#Display the dataframe
print(df)

# %matplotlib inline
import matplotlib.pyplot as plt #https://matplotlib.org/3.2.1/contents.html
# from matplotlib import pyplot as plt #this syntax works too

plt.plot(df.x, df.y, color="grey", marker = "o")
plt.annotate('bug on your screen',(1.333, 0))
plt.plot([0, 1],[2, 2], color='red', lw=5)
#plt.xlabel('x')
#plt.ylabel('y')
#plt.grid()
plt.show()
# Out:
#     x     y
# 0  -5  35.5
# 1  -4  22.0
# 2  -3  11.5
# 3  -2   4.0
# 4  -1  -0.5
# 5   0  -2.0
# 6   1  -0.5
# 7   2   4.0
# 8   3  11.5
# 9   4  22.0
# 10  5  35.5

# %%
import math
print(math.e)
print(math.pi)
print(math.log(math.e))
print(math.log10(100))

from random import randint
for i in range(5,8):
    print(i, randint(i,10))
    
aa = [the_answer(a) for a in range(3,6)] #create an array from another range/array

print(aa)
# Out:
# 2.718281828459045
# 3.141592653589793
# 1.0
# 2.0
# 5 10
# 6 8
# 7 8
# [42, 42, 42]

# %%
import numpy as np
a = np.array(range(0,4)) #numpy array https://numpy.org/doc/stable/user/basics.creation.html
print(a)
print (np.linspace(1,8)) #looks like a range
# Out:
# [0 1 2 3]
# [1.         1.14285714 1.28571429 1.42857143 1.57142857 1.71428571
#  1.85714286 2.         2.14285714 2.28571429 2.42857143 2.57142857
#  2.71428571 2.85714286 3.         3.14285714 3.28571429 3.42857143
#  3.57142857 3.71428571 3.85714286 4.         4.14285714 4.28571429
#  4.42857143 4.57142857 4.71428571 4.85714286 5.         5.14285714
#  5.28571429 5.42857143 5.57142857 5.71428571 5.85714286 6.
#  6.14285714 6.28571429 6.42857143 6.57142857 6.71428571 6.85714286
#  7.         7.14285714 7.28571429 7.42857143 7.57142857 7.71428571
#  7.85714286 8.        ]

# %%
#integrate a quadratic between limits
import scipy.integrate as integrate
i, e = integrate.quad(lambda x: math.sin(x) + x**2 + 2 * x + 1, 0, 3)
print(i, e)
# Out:
# 22.989992496600443 2.55240190056854e-13

# %%
#vectors: magnitude, cross product, plotting
import math
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib.patches import Polygon

# define our vectors
v = np.array([2,1])
s = np.array([-3,2])
vs = v + s

# get the magnitudes
vMag = np.linalg.norm(v)
sMag = np.linalg.norm(s)

# calculate the cosine of theta
# @ same as 
cos = np.dot(v,s) / (vMag * sMag)
cos = (v @ s) / (vMag * sMag)

# so theta (in degrees) is:
theta = math.degrees(math.acos(cos))

print('Angle: ' + str(theta) + 'deg')

origin = [0], [0]
plot1, plot2 = plt.subplots()
plt.axis('equal')
plt.grid()
plt.ticklabel_format(style='plain', axis='both', scilimits=(0,0))
plt.quiver(*origin, *s, scale=10)
plt.quiver(*origin, *v, color='r', scale=10)

verts = np.multiply([[0,0] , s, vs, v],.01)

print (verts)

poly = Polygon(verts, facecolor='orange')

plot2.add_patch(poly)

plt.show()

print(*s)

print(np.multiply(s,3)) #multiply all parts of array by 3

print(*[2,1])

v = np.append(v,0) #np.append RETURNS A NEW ARRAY WITH AN EXTRA ELEMENT
s = np.append(s,0)
t=np.cross(v,s)
print(v)
print(t) # A vector at right angles to both existing vectors, ie just the z part
# Out:
# Angle: 119.74488129694222deg
# [[ 0.    0.  ]
#  [-0.03  0.02]
#  [-0.01  0.03]
#  [ 0.02  0.01]]
# -3 2
# [-9  6]
# 2 1
# [2 1 0]
# [0 0 7]

# %%
# Matrices
import numpy as np
# use np.array or np.matrix... use np.array to save confusion
D=np.array([[1,2],[3,4]])
D+=3 # add constant to each element
print('a + 3')
print(D)
print(D.T) #transpose

A = np.array([[1,2,3],
              [4,5,6]])
B = np.array([[9,8],
              [7,6],
              [5,4]
              # no you can't sneak an extra row in here,[3,2]
             ])
print('A.B')
print(np.dot(A,B))
print('A @ B') # same result
# print(A @ B)

C = D @ np.linalg.inv(D) # multiply by inverse, get I identity matrix

print(C)

# applicable to linear equations
#ax + by = c
#dx + ey = f
#[[a,b],[d,e]].[x,y] = [c,f]
#[x,y]=A.T . [c,f]
# Out:
# a + 3
# [[4 5]
#  [6 7]]
# [[4 6]
#  [5 7]]
# A.B
# [[ 38  32]
#  [101  86]]
# A @ B
# [[ 1.00000000e+00  0.00000000e+00]
#  [-1.77635684e-15  1.00000000e+00]]

# %%
# Matrix transformations
import numpy as np
v = np.array([1,2])
A = np.array([[2,3],
              [5,2],
              [1,1]])

t = A@v #apply transformation A to vector v
print (t)

# Afine transformations: The matrix defines the features, the first vector is the coefficients, and the bias vector is the intercept.

A = np.array([[2,0],
              [0,3]])
print('eigenvalues and eigenvectors of A')
eVals, eVecs = np.linalg.eig(A) 
print(eVals)
print(eVecs)
# Out:
# [8 9 3]
# eigenvalues and eigenvectors of A
# [2. 3.]
# [[1. 0.]
#  [0. 1.]]

# %%
#graph with a polygon
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.patches import Polygon
# %matplotlib inline

# Define function g
def g(x):
    return 3 * x**2 + 2 * x + 1

# Create an array of x values from 0 to 10
x = range(0, 11)

# Get the corresponding y values from the function
y = [g(a) for a in x]

# Set up the plot
fig, ax = plt.subplots()
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid()

# Plot x against g(x)
plt.plot(x,y, color='purple')

# Make the shaded region
ix = np.linspace(0, 3)
iy = g(ix)
verts = [(0, 0)] + list(zip(ix, iy)) + [(3, 0)]
poly = Polygon(verts, facecolor='orange')
ax.add_patch(poly)

plt.show()

# %%
#3d graph

#https://matplotlib.org/3.1.0/gallery/mplot3d/surface3d.html

# This import registers the 3D projection, but is otherwise unused.
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import

import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np


fig = plt.figure()
ax = fig.gca(projection='3d')

# Make data.
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

# Plot the surface.
surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)

# Customize the z axis.
ax.set_zlim(-1.01, 1.01)
ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()

# %%
#Visualising data
import statsmodels.api as sm  
df = sm.datasets.get_rdataset('GaltonFamilies', package='HistData').data
# Create a data frame of child counts
# there's a row for each child, so we need to filter to one row per family to avoid over-counting
families = df[['family','father', 'children']].drop_duplicates()
# print(families)
# Now count number of rows for each 'children' value, and sort by the index (children)
childCounts = families['children'].value_counts().sort_index()


# Plot a bar chart
# %matplotlib inline
from matplotlib import pyplot as plt

childCounts.plot(kind='bar', title='Family Size')
plt.xlabel('Number of Children')
plt.ylabel('Families')
plt.show()

df['father'].plot.hist(title='Father Heights')
plt.xlabel('Height')
plt.ylabel('Frequency')
plt.show()

# Create a data frame of heights (father vs child)
parentHeights = df[['midparentHeight', 'childHeight']]

# Plot a scatter plot chart
parentHeights.plot(kind='scatter', title='Parent vs Child Heights', x='midparentHeight', y='childHeight')
plt.xlabel('Avg Parent Height')
plt.ylabel('Child Height')
plt.show()

# %%
# statistics
import pandas as pd
# %matplotlib inline
from matplotlib import pyplot as plt
import scipy.stats as stats


df = pd.DataFrame({'Name': ['Dan', 'Joann', 'Pedro', 'Rosie', 'Ethan', 'Vicky', 'Frederic'],
                   'Salary':[50000,54000,50000,189000,55000,40000,59000],
                   'Hours':[41,40,36,30,35,39,40],
                   'Grade':[50,50,46,95,50,5,57]})

print (df['Salary'].mean())
print (df['Salary'].mode()) #note 2 modes
print (df['Salary'].median())

print('interesting stats about each column')
print(df.describe())

salary = df['Salary']
salary.plot.hist(title='Salary Distribution', color='lightblue', bins=25)  

density = stats.gaussian_kde(salary)
n, x, _ = plt.hist(salary, histtype='step', normed=True, bins=25)  
plt.plot(x, density(x)*5)
plt.axvline(salary.mean(), color='magenta', linestyle='dashed', linewidth=2)
plt.axvline(salary.median(), color='green', linestyle='dashed', linewidth=2)
plt.show()

numcols = ['Salary', 'Hours', 'Grade']
for col in numcols:
    print(df[col].name + ' skewness: ' + str(df[col].skew()))
    print(df[col].name + ' kurtosis: ' + str(df[col].kurt()))
    density = stats.gaussian_kde(df[col])
    n, x, _ = plt.hist(df[col], histtype='step', normed=True, bins=25)  
    plt.plot(x, density(x)*6)
    plt.show()
    print('\n')

print('Frederics grade of 57 is what percentile position?')
print(stats.percentileofscore(df['Grade'], 57, 'strict'))
# Out:
# 71000.0
# 0    50000
# dtype: int64
# 54000.0
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6499: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")
# Salary skewness: 2.57316410755049
# Salary kurtosis: 6.719828837773431
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6499: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")
# Hours skewness: -1.194570307262883
# Hours kurtosis: 0.9412265624999989
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6499: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")
# ...

# %%
P=.4
#Ways of choosing k from n nCk 
#Probability of first k tests being a success out of N tests P**k * (1-P)**N-k
p1=P**3*(1-P)**2
print(p1)
from scipy import special as sps
print(p1*sps.comb(5,3))

P=.1
p2=P**2*(1-P)**1
print(p2)
print(p2*sps.comb(3,2))
# Out:
# 0.023040000000000005
# 0.23040000000000005
# 0.009000000000000003
# 0.02700000000000001

# %%
import pandas as pd
cfs=[
180.5,
178.8,
176.2,
177.1,
178.75,
179.25,
175.4,
178.2,
177.25,
177.5,
179.9,
180.8,
177.75,
179.5,
179.25,
178.5,
178.8,
178.5,
176.5,
178.76,
181.6]

df=pd.DataFrame({'heights':cfs})
df.describe()
# Out:
#           heights
# count   21.000000
# mean   178.514762
# std      1.538920
# min    175.400000
# 25%    177.500000
# 50%    178.750000
# 75%    179.250000
# max    181.600000

# %%
import pandas as pd
import scipy.stats as stats
from scipy.stats import norm as norm
# %matplotlib inline
import matplotlib.pyplot as plt
cfs=[
180.5,
178.8,
176.2,
177.1,
178.75,
179.25,
175.4,
178.2,
177.25,
177.5,
179.9,
180.8,
177.75,
179.5,
179.25,
178.5,
178.8,
178.5,
176.5,
178.76,
181.6]

df=pd.DataFrame({'heights':cfs})
df.describe()



df=pd.DataFrame({'coffee':cfs})
#df.describe()


#df.hist()
#coffee=df['coffee']



print('wtaf')

#density=stats.gaussian_kde(coffee)
#print(density)

#n, x, _ = plt.hist(coffee, histtype='step', normed=True, bins=5)

#plt.plot(x, density(x))
#plt.show()
# Out:
# wtaf

# %%
import pandas as pd

# %matplotlib inline
import matplotlib.pyplot as plt
import scipy.stats as stats
heights=[172,
174,
176,
172,
172,
173,
176,
172,
177,
174,
176,
175,
176,
169,
175,
174,
174,
174,
175,
173,
171,
171,
175,
175,
173,
175,
175]
df=pd.DataFrame({'heights':heights})
#df.describe()
#df.median()
#df.mode()
df.hist()
heightsdf=df['heights']
density=stats.gaussian_kde(heightsdf)
n, x, _ = plt.hist(heightsdf, histtype='step', normed=True, bins=25)  
plt.plot(x, density(x)*5)
#plt.axvline(salary.mean(), color='magenta', linestyle='dashed', linewidth=2)
#plt.axvline(salary.median(), color='green', linestyle='dashed', linewidth=2)
plt.show()

# %%
wts=[184,
180,
181,
184,
182,
181,
182,
182,
183,
182,
181,
182,
182,
180,
183,
181,
184,
183,
182,
182,
183,
182,
183,
181,
180,
181,
183
]
df=pd.DataFrame({'wts':wts})
#df.describe()

#df.hist()

# %matplotlib inline
from matplotlib import pyplot as plt
import scipy.stats as stats

weights=df['wts']

density=stats.gaussian_kde(weights)

n, x, _ = plt.hist(weights, histtype='step',normed=True, bins=25)

plt.plot(x,density(x))

plt.show()

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np

def a(x):
    return 2*(x**4)-3*(x**2)+(2*x)-20

def aa(x):
    return 8*x**3-6*x+2

x = np.arange(-2,4,0.5)
y = [a(i) for i in x]
yy = [aa(i) for i in x]

plt.plot(x,y)
plt.plot(x,yy,color="red")

print(aa(-1))
# Out:
# 0

# %%
def c(x):
    return -2*x**2+30*x+3


x=np.arange(6,8.5,0.5)
y=[c(i) for i in x]
plt.plot(x, y)

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np

def g(x):
    return 2*(x**2)/(x-2)

x = np.arange(-2,8,0.5)

import pandas as pd

# Create a dataframe with an x column containing values from -10 to 10
df = pd.DataFrame ({'x': np.arange(-3, 1.9,0.2)})

# Add a y column by applying the solved equation to x
df['y'] = g(df['x'])

#Display the dataframe
df

plt.plot(x, g(x))
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/ipykernel/__main__.py:6: RuntimeWarning: divide by zero encountered in true_divide
